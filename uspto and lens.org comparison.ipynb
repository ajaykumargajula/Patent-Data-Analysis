# %%
import pandas as pd
import numpy as np
data=pd.read_csv("E:\\BABI\\Capstone\\Capstone\\Capstone_Legal Analytics\\Data\\AllPatents.csv",index_col=0)
data_samsung=data[data["Company"]=="Samsung"]
data_samsung.head()

#data_subset=data_samsung[["URL","Company","Lens ID","Application Number"]]
# Out:
# C:\Users\AjayKumar\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3049: DtypeWarning: Columns (24) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
#    # Jurisdiction Kind  Publication Number              Lens ID  \
# 0  1           US   B2       US 7502191 B2  099-043-415-470-20X
# 1  2           US   B2       US 7542449 B2  029-114-805-036-51X
# 2  3           US   B2       US 7253978 B2  131-936-660-177-791
# 3  4           US   A1  US 2005/0264909 A1  061-673-469-899-690
# 4  5           US   A1  US 2006/0133320 A1  143-815-448-852-15X
#
#   Publication Date  Publication Year Application Number Application Date  \
# 0       2009-10-03              2009      US 12646205 A       2005-10-05
# 1       2009-02-06              2009      US 28640905 A       2005-11-25
# 2       2007-07-08              2007      US 17641405 A       2005-06-07
# ...

# %%
data_subset=data_samsung[["URL","Company","Lens ID","Application Number"]]
data_application=data_subset["Application Number"].str.split(" ",n=3,expand=True)

# %%
data_application.columns=["Country","Application_Number","Application_status"]
data_application.head()
# Out:
#   Country Application_Number Application_status
# 0      US           12646205                  A
# 1      US           28640905                  A
# 2      US           17641405                  A
# 3      US           17641405                  A
# 4      US           28640905                  A

# %%
samsung=pd.concat([data_subset.reset_index(drop=True),data_application],axis=1)
samsung.head()
# Out:
#                                     URL  Company              Lens ID  \
# 0  https://lens.org/099-043-415-470-20X  Samsung  099-043-415-470-20X
# 1  https://lens.org/029-114-805-036-51X  Samsung  029-114-805-036-51X
# 2  https://lens.org/131-936-660-177-791  Samsung  131-936-660-177-791
# 3  https://lens.org/061-673-469-899-690  Samsung  061-673-469-899-690
# 4  https://lens.org/143-815-448-852-15X  Samsung  143-815-448-852-15X
#
#   Application Number Country Application_Number Application_status
# 0      US 12646205 A      US           12646205                  A
# 1      US 28640905 A      US           28640905                  A
# 2      US 17641405 A      US           17641405                  A
# 3      US 17641405 A      US           17641405                  A
# 4      US 28640905 A      US           28640905                  A

# %%
usptodata=pd.read_csv("E:\\BABI\\Capstone\\Capstone\\Capstone_Legal Analytics\\Data\\USPTO\\Samsung\\Samsung_Abstract_Unique.csv")
print(usptodata.shape)
usptodata.head()
# Out:
# (111657, 9)
# C:\Users\AjayKumar\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3049: DtypeWarning: Columns (4) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
#    Unnamed: 0  Unnamed: 0.1  \
# 0           0             1
# 1           1             2
# 2           2             3
# 3           3             4
# 4           4             5
#
#                                      patent_abstract patent_date patent_id  \
# 0  A hermetically sealed optical component includ...  2018-06-19  10000015
# 1  An optoelectronic material includes a first or...  2018-06-19  10000462
# 2  An anti-EGFR/anti-HER3 antibody or antigen bin...  2018-06-19  10000569
# 3  A polymer including a first structural unit re...  2018-06-19  10000604
# 4  A method of manufacturing a fluoride phosphor,...  2018-06-19  10000695
#
#                                         patent_title patent_type  \
# ...

# %%
uspto_application=usptodata["applications"].str.split(",",n=1,expand=True)
uspto_application.columns=["string1","string2"]
uspto_application.head()
# Out:
#       string1     string2
# 0  2016-05-19   15/159489
# 1  2015-02-10   14/618597
# 2  2015-04-22   14/692934
# 3  2016-05-06   15/148477
# 4  2015-12-28   14/981887

# %%
uspto_app=uspto_application["string2"].str.split("/",n=1,expand=True)

uspto_app.columns=["c","Application_Number"]

# %%
uspto_samsung=pd.concat([usptodata.reset_index(drop=True),uspto_app],axis=1)

# %%
uspto_samsung.drop(columns=["Unnamed: 0","Unnamed: 0.1","c"])
# Out:
#                                           patent_abstract patent_date  \
# 0       A hermetically sealed optical component includ...  2018-06-19
# 1       An optoelectronic material includes a first or...  2018-06-19
# 2       An anti-EGFR/anti-HER3 antibody or antigen bin...  2018-06-19
# 3       A polymer including a first structural unit re...  2018-06-19
# 4       A method of manufacturing a fluoride phosphor,...  2018-06-19
# 5       Quantum dots and methods of making quantum dot...  2018-06-19
# 6       Disclosed herein is a washing machine capable ...  2018-06-19
# 7       A refrigerator includes a refrigerating compar...  2018-06-19
# 8       A laminated structure includes a polymer layer...  2018-06-19
# 9       Temperature sensing circuits are provided. The...  2018-06-19
# 10      A temperature sensor having calibration functi...  2018-06-19
# 11      A surface inspecting method includes: irradiat...  2018-06-19
# ...

# %%
list1=list(samsung["Application_Number"])
list2=list(uspto_samsung["Application_Number"])
match=[]
nomatch=[]
for item in list2:
    if item in list1:
        match.append(item)
    else:
        nomatch.append(item)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-29-4176f410ebc3> in <module>
#       4 nomatch=[]
#       5 for item in list2:
# ----> 6     if list1.str.contains(item):
#       7         match.append(item)
#       8     else:
#
# AttributeError: 'list' object has no attribute 'str'

# %%
nomatch
# Out:
# ['159489',
#  '618597',
#  '692934',
#  '148477',
#  '981887',
#  '284251',
#  '590197',
#  '735296',
#  '981217',
#  '569861',
#  '475154',
#  '955635',
#  '062831',
#  '368890',
#  '131685',
#  '062397',
#  '142014',
#  '822307',
#  '707195',
#  '034014',
#  '697166',
#  '373008',
#  '374374',
#  '702532',
#  '423211',
#  '605538',
#  '110031',
#  '291266',
#  '169044',
#  '594686',
#  '790390',
#  '678968',
#  '678977',
#  '209043',
#  '938994',
#  '980363',
#  '927274',
#  '152512',
#  '068931',
#  '711390',
#  '683774',
#  '172751',
#  '198155',
#  '284477',
#  '154070',
#  '295724',
#  '828107',
#  '246822',
#  '015609',
#  '105907',
#  '444192',
#  '210808',
#  '490231',
#  '730379',
#  '222244',
#  '145924',
#  '089604',
#  '423725',
#  '380770',
#  '616471',
#  '466111',
#  '448697',
#  '312789',
#  '160288',
#  '431234',
#  '236564',
#  '164246',
#  '602131',
#  '226314',
#  '454210',
#  '367033',
#  '953104',
#  '432983',
#  '819679',
#  '081997',
#  '274092',
# ...

# %%
applicatio=pd.concat([samsung["Application_Number"],uspto_samsung["Application_Number"],usptodata["patent_id"]],axis=1)

# %%
applicatio.to_csv("samsung.csv")

# %%
data_avail=data_samsung[data_samsung["Application Number"].str.contains("284251")]
data_avail
# Out:
#             # Jurisdiction Kind  Publication Number              Lens ID  \
# 136363   9347           US   A1  US 2015/0013589 A1  190-443-951-481-384
# 142501  15485           US   B2      US 10000862 B2  109-266-018-873-477
#
#        Publication Date  Publication Year Application Number Application Date  \
# 136363       2015-01-15              2015  US 201414284251 A       2014-05-21
# 142501       2018-06-19              2018  US 201414284251 A       2014-05-21
#
#                                          Priority Numbers  ... Sequence Count  \
# 136363  US 201161562459 P 20111122;;US 201261678877 P ...  ...              0
# 142501  US 201161562459 P 20111122;;US 201261678877 P ...  ...              0
#
#                                       CPC Classifications  \
# 136363  C30B7/14;;B22F1/0018;;B22F9/24;;B82Y30/00;;B82...
# 142501  C30B7/14;;B22F1/0018;;B22F9/24;;B82Y30/00;;B82...
#
#                                      IPCR Classifications US Classifications  \
# ...

# %%
list1=list(data_samsung["Application Number"])
list2=list(uspto_samsung["Application_Number"])
match=[]
nomatch=[]
for item in list2:
    if item in list1:
        match.append(item)
    else:
        nomatch.append(item)

# %%
pd.concat([data_samsung["Application Number"],uspto_samsung["Application_Number"]],axis=1).to_csv("samsung1.csv")

# %%
data_avail=data_samsung[data_samsung["Publication Number"].str.contains("0103287")]
data_avail
# Out:
#             # Jurisdiction Kind  Publication Number              Lens ID  \
# 185534  24307           US   A1  US 2019/0103287 A1  165-594-019-712-353
# 197091  11403           US   A1  US 2019/0103287 A1  165-594-019-712-353
# 200534   3431           US   A1  US 2019/0103287 A1  165-594-019-712-353
#
#        Publication Date  Publication Year Application Number Application Date  \
# 185534       2019-04-04              2019  US 201816106739 A       2018-08-21
# 197091       2019-04-04              2019  US 201816106739 A       2018-08-21
# 200534       2019-04-04              2019  US 201816106739 A       2018-08-21
#
#                  Priority Numbers  ... Sequence Count  \
# 185534  KR 20170127794 A 20170929  ...              0
# 197091  KR 20170127794 A 20170929  ...              0
# 200534  KR 20170127794 A 20170929  ...              0
#
#                                       CPC Classifications  \
# 185534  H01L21/32136;;C23F3/04;;H01L21/02063;;H01L21/3...
# ...

# %%
data_publication=data_samsung["Publication Number"].str.split(" ",n=2,expand=True)
data_publication
# Out:
#          0             1   2
# 0       US       7502191  B2
# 1       US       7542449  B2
# 2       US       7253978  B2
# 3       US  2005/0264909  A1
# 4       US  2006/0133320  A1
# 5       US  2006/0138365  A1
# 6       US       7256409  B2
# 7       US  2006/0131522  A1
# 8       US  2005/0207055  A1
# 9       US  2005/0223544  A1
# 10      US       7093346  B2
# 11      US       7479445  B2
# 12      US       7479455  B2
# 13      US       7480009  B2
# 14      US       7480005  B2
# 15      US       7479442  B2
# 16      US       7479952  B2
# 17      US       7480845  B2
# 18      US       7480269  B2
# 19      US       7480341  B2
# 20      US       7480922  B2
# 21      US       7481631  B2
# 22      US       7482100  B2
# 23      US       7482224  B2
# 24      US       7483156  B2
# 25      US       7482616  B2
# 26      US       7483038  B2
# 27      US       7483228  B2
# 28      US       7483320  B2
# 29      US       7483497  B2
# ...     ..           ...  ..
# ...
